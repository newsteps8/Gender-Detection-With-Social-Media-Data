# %%
import lightgbm as lgb
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.utils import shuffle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools
# %matplotlib inline
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from scipy.sparse import hstack, csr_matrix, vstack
import pickle as pickle

data = pd.read_csv('/content/drive/My Drive/gender_data.csv', engine='python' , encoding='utf-8', error_bad_lines=False)
#data.drop('Unnamed: 0',axis=1,inplace=True)
data.Gender = data.Gender.map({'Women':1,'Men':0})
data.head()
# Out:
#                                                 text  Gender
# 0  Her şeyin doğallığı güzeldir.\nUsta olan doğad...       0
# 1                                   psikolojim bozuk       1
# 2  Toprak ananın şifalı mucizeleriyle tanışın: 8 ...       1
# 3  Bu hatlar neden çekmiyor öleceksek söyleyin şi...       1
# 4  Rüzgar eserken hindi sesi gibi bir ses geliyor...       0

# %%
df = data.copy()
df['text'] = df['text'].astype(str).fillna(' ')
# Lower case comment
df['text'] = df['text'].str.lower()
# Add num words of comment as feature
df['num_words'] = df['text'].apply(lambda s: len(s.split()))
# Add num words unique of comment as feature
df['num_unique_words'] = df['text'].apply(lambda s: len(set(w for w in s.split())))
# Add num words unique per num words of comment as feature
df['words_vs_unique'] = df['num_unique_words'] / df['num_words'] * 100

# %%
from sklearn.model_selection import train_test_split

train_df, test_df= train_test_split(df, test_size=0.25, random_state=39, stratify=df.Gender)
y_train = train_df['Gender'].values

# %%
train_df
# Out:
#                                                       text  ...  words_vs_unique
# 2521095  ayıp ettinnn aaaa,  bizim karnabahar tarlasını...  ...        90.909091
# 2363237  suyun bulandığı yerden geliyoruz. suyun gözesi...  ...        92.307692
# 2228785  kısmet olursa hepimiz uçacağız birgün. 20 yıl ...  ...       100.000000
# 1855674  her yeri bayır baca olan bir yerde(şırnak) yap...  ...       100.000000
# 1758361  tugba bosverizm sen ben grupta konusurken beni...  ...       100.000000
# ...                                                    ...  ...              ...
# 2697301  hahaha bilgili mi :) daha alfabeyi bilmiyor. o...  ...       100.000000
# 1666075  yemek yemeye daima vakit bulurum https://twitt...  ...       100.000000
# 2222781  haber başlığı böyle atılırsa alay konusu olmak...  ...       100.000000
# 2426757    nasıl yakalamış!! :))pic.twitter.com/ccw149aykl  ...       100.000000
# 3337807  ek depozito da mı var ?? gerçekten bıktım aq c...  ...        92.857143
#
# [2676762 rows x 5 columns]

# %%
# Just keep statistic feature to process by model
EXCLUED_COLS = ['text','Gender']
static_cols = [c for c in train_df.columns if not c in EXCLUED_COLS]
print(static_cols)
X_train_static = train_df[static_cols].values
X_test_static = test_df[static_cols].values
print(X_train_static.shape, X_test_static.shape)
# Out:
# ['num_words', 'num_unique_words', 'words_vs_unique']
# (2676762, 3) (892254, 3)

# %%
tfidf = TfidfVectorizer(
    min_df = 5, 
    max_df = 0.8, 
    max_features=10000,
    sublinear_tf=True
)

# %%
train_comments = train_df['text'].values
test_comments = test_df['text'].values
X_train_tfidf = tfidf.fit_transform(train_comments)
X_test_tfidf = tfidf.transform(test_comments)

# %%
with open('vectorizer.pk', 'wb') as fin:
    pickle.dump(tfidf, fin)

# %%
X_train = hstack([X_train_tfidf, csr_matrix(X_train_static)]).tocsr()
X_test = hstack([X_test_tfidf, csr_matrix(X_test_static)]).tocsr()

# %%
X_train_split, X_valid, y_train_split, y_valid = train_test_split(X_train, y_train, test_size=0.1)

# %%
param = {'num_leaves':100, 'num_trees':300, 'objective':'binary', "max_bin":255, "learning_rate":0.1}

# %%
train_data = lgb.Dataset(X_train_split, y_train_split)
valid_data = lgb.Dataset(X_valid, y_valid)

# %%
bst = lgb.train(param, train_data, num_boost_round=500, valid_sets=[valid_data])
print("accuracy: {}".format(accuracy_score(y_valid, 1*(bst.predict(X_valid)>0.5))))
# Out:
# /usr/local/lib/python3.6/dist-packages/lightgbm/engine.py:118: UserWarning: Found `num_trees` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid_0's binary_logloss: 0.661435
# [2]	valid_0's binary_logloss: 0.651003
# [3]	valid_0's binary_logloss: 0.642308
# [4]	valid_0's binary_logloss: 0.634921
# [5]	valid_0's binary_logloss: 0.628765
# [6]	valid_0's binary_logloss: 0.623626
# [7]	valid_0's binary_logloss: 0.619069
# [8]	valid_0's binary_logloss: 0.615254
# [9]	valid_0's binary_logloss: 0.611965
# [10]	valid_0's binary_logloss: 0.609077
# [11]	valid_0's binary_logloss: 0.606561
# [12]	valid_0's binary_logloss: 0.604271
# [13]	valid_0's binary_logloss: 0.602364
# [14]	valid_0's binary_logloss: 0.600727
# [15]	valid_0's binary_logloss: 0.599167
# [16]	valid_0's binary_logloss: 0.59753
# [17]	valid_0's binary_logloss: 0.59635
# [18]	valid_0's binary_logloss: 0.59518
# [19]	valid_0's binary_logloss: 0.593889
# [20]	valid_0's binary_logloss: 0.592719
# [21]	valid_0's binary_logloss: 0.591631
# [22]	valid_0's binary_logloss: 0.590538
# [23]	valid_0's binary_logloss: 0.58948
# [24]	valid_0's binary_logloss: 0.588712
# [25]	valid_0's binary_logloss: 0.58776
# [26]	valid_0's binary_logloss: 0.58702
# [27]	valid_0's binary_logloss: 0.586267
# [28]	valid_0's binary_logloss: 0.585562
# [29]	valid_0's binary_logloss: 0.584738
# [30]	valid_0's binary_logloss: 0.584073
# [31]	valid_0's binary_logloss: 0.583453
# [32]	valid_0's binary_logloss: 0.58293
# [33]	valid_0's binary_logloss: 0.582342
# [34]	valid_0's binary_logloss: 0.581802
# [35]	valid_0's binary_logloss: 0.581263
# [36]	valid_0's binary_logloss: 0.580792
# [37]	valid_0's binary_logloss: 0.580244
# [38]	valid_0's binary_logloss: 0.579805
# [39]	valid_0's binary_logloss: 0.579354
# [40]	valid_0's binary_logloss: 0.578976
# [41]	valid_0's binary_logloss: 0.578511
# [42]	valid_0's binary_logloss: 0.578045
# [43]	valid_0's binary_logloss: 0.577647
# [44]	valid_0's binary_logloss: 0.577259
# [45]	valid_0's binary_logloss: 0.576843
# [46]	valid_0's binary_logloss: 0.57643
# [47]	valid_0's binary_logloss: 0.576035
# [48]	valid_0's binary_logloss: 0.575684
# [49]	valid_0's binary_logloss: 0.575368
# [50]	valid_0's binary_logloss: 0.575032
# [51]	valid_0's binary_logloss: 0.574698
# [52]	valid_0's binary_logloss: 0.574394
# [53]	valid_0's binary_logloss: 0.574098
# [54]	valid_0's binary_logloss: 0.573818
# [55]	valid_0's binary_logloss: 0.573498
# [56]	valid_0's binary_logloss: 0.573215
# [57]	valid_0's binary_logloss: 0.572921
# [58]	valid_0's binary_logloss: 0.572621
# [59]	valid_0's binary_logloss: 0.572353
# [60]	valid_0's binary_logloss: 0.572074
# [61]	valid_0's binary_logloss: 0.571819
# [62]	valid_0's binary_logloss: 0.571556
# [63]	valid_0's binary_logloss: 0.571333
# [64]	valid_0's binary_logloss: 0.571075
# [65]	valid_0's binary_logloss: 0.570844
# [66]	valid_0's binary_logloss: 0.570616
# [67]	valid_0's binary_logloss: 0.570399
# [68]	valid_0's binary_logloss: 0.570143
# [69]	valid_0's binary_logloss: 0.569936
# [70]	valid_0's binary_logloss: 0.569686
# [71]	valid_0's binary_logloss: 0.569467
# [72]	valid_0's binary_logloss: 0.569257
# [73]	valid_0's binary_logloss: 0.569022
# [74]	valid_0's binary_logloss: 0.568826
# [75]	valid_0's binary_logloss: 0.568639
# [76]	valid_0's binary_logloss: 0.568444
# [77]	valid_0's binary_logloss: 0.56825
# [78]	valid_0's binary_logloss: 0.56806
# [79]	valid_0's binary_logloss: 0.567835
# [80]	valid_0's binary_logloss: 0.567621
# [81]	valid_0's binary_logloss: 0.567415
# [82]	valid_0's binary_logloss: 0.567238
# [83]	valid_0's binary_logloss: 0.567065
# [84]	valid_0's binary_logloss: 0.566895
# [85]	valid_0's binary_logloss: 0.566714
# [86]	valid_0's binary_logloss: 0.566543
# [87]	valid_0's binary_logloss: 0.566366
# [88]	valid_0's binary_logloss: 0.56619
# [89]	valid_0's binary_logloss: 0.566023
# [90]	valid_0's binary_logloss: 0.565873
# [91]	valid_0's binary_logloss: 0.565719
# [92]	valid_0's binary_logloss: 0.565538
# [93]	valid_0's binary_logloss: 0.565397
# [94]	valid_0's binary_logloss: 0.565249
# [95]	valid_0's binary_logloss: 0.565113
# [96]	valid_0's binary_logloss: 0.564984
# [97]	valid_0's binary_logloss: 0.564829
# [98]	valid_0's binary_logloss: 0.564659
# [99]	valid_0's binary_logloss: 0.564522
# [100]	valid_0's binary_logloss: 0.564373
# [101]	valid_0's binary_logloss: 0.564212
# [102]	valid_0's binary_logloss: 0.564071
# [103]	valid_0's binary_logloss: 0.563931
# [104]	valid_0's binary_logloss: 0.563816
# [105]	valid_0's binary_logloss: 0.563678
# [106]	valid_0's binary_logloss: 0.563545
# [107]	valid_0's binary_logloss: 0.563418
# [108]	valid_0's binary_logloss: 0.563302
# [109]	valid_0's binary_logloss: 0.563167
# [110]	valid_0's binary_logloss: 0.56301
# [111]	valid_0's binary_logloss: 0.562886
# [112]	valid_0's binary_logloss: 0.562764
# [113]	valid_0's binary_logloss: 0.562646
# [114]	valid_0's binary_logloss: 0.562533
# [115]	valid_0's binary_logloss: 0.562421
# [116]	valid_0's binary_logloss: 0.562304
# [117]	valid_0's binary_logloss: 0.562197
# [118]	valid_0's binary_logloss: 0.562051
# [119]	valid_0's binary_logloss: 0.561946
# [120]	valid_0's binary_logloss: 0.561826
# [121]	valid_0's binary_logloss: 0.56171
# [122]	valid_0's binary_logloss: 0.561589
# [123]	valid_0's binary_logloss: 0.561479
# [124]	valid_0's binary_logloss: 0.561387
# [125]	valid_0's binary_logloss: 0.561285
# [126]	valid_0's binary_logloss: 0.561186
# [127]	valid_0's binary_logloss: 0.561063
# [128]	valid_0's binary_logloss: 0.560955
# [129]	valid_0's binary_logloss: 0.560852
# [130]	valid_0's binary_logloss: 0.56076
# [131]	valid_0's binary_logloss: 0.560674
# [132]	valid_0's binary_logloss: 0.560581
# [133]	valid_0's binary_logloss: 0.560474
# [134]	valid_0's binary_logloss: 0.560375
# [135]	valid_0's binary_logloss: 0.560267
# [136]	valid_0's binary_logloss: 0.56015
# [137]	valid_0's binary_logloss: 0.560045
# [138]	valid_0's binary_logloss: 0.559964
# [139]	valid_0's binary_logloss: 0.559862
# [140]	valid_0's binary_logloss: 0.55979
# [141]	valid_0's binary_logloss: 0.559701
# [142]	valid_0's binary_logloss: 0.559608
# [143]	valid_0's binary_logloss: 0.559523
# [144]	valid_0's binary_logloss: 0.559426
# [145]	valid_0's binary_logloss: 0.55933
# [146]	valid_0's binary_logloss: 0.559262
# [147]	valid_0's binary_logloss: 0.559169
# [148]	valid_0's binary_logloss: 0.559092
# [149]	valid_0's binary_logloss: 0.559015
# [150]	valid_0's binary_logloss: 0.558918
# [151]	valid_0's binary_logloss: 0.558842
# [152]	valid_0's binary_logloss: 0.558755
# [153]	valid_0's binary_logloss: 0.558685
# [154]	valid_0's binary_logloss: 0.558585
# [155]	valid_0's binary_logloss: 0.558506
# [156]	valid_0's binary_logloss: 0.558435
# [157]	valid_0's binary_logloss: 0.558363
# [158]	valid_0's binary_logloss: 0.558266
# [159]	valid_0's binary_logloss: 0.558189
# [160]	valid_0's binary_logloss: 0.558098
# [161]	valid_0's binary_logloss: 0.558026
# [162]	valid_0's binary_logloss: 0.557945
# [163]	valid_0's binary_logloss: 0.557875
# [164]	valid_0's binary_logloss: 0.557803
# [165]	valid_0's binary_logloss: 0.557745
# [166]	valid_0's binary_logloss: 0.557671
# [167]	valid_0's binary_logloss: 0.5576
# [168]	valid_0's binary_logloss: 0.557525
# [169]	valid_0's binary_logloss: 0.557456
# [170]	valid_0's binary_logloss: 0.557367
# [171]	valid_0's binary_logloss: 0.557304
# [172]	valid_0's binary_logloss: 0.557228
# [173]	valid_0's binary_logloss: 0.557169
# [174]	valid_0's binary_logloss: 0.557091
# [175]	valid_0's binary_logloss: 0.557019
# [176]	valid_0's binary_logloss: 0.556951
# [177]	valid_0's binary_logloss: 0.556894
# [178]	valid_0's binary_logloss: 0.556831
# [179]	valid_0's binary_logloss: 0.55677
# [180]	valid_0's binary_logloss: 0.556709
# [181]	valid_0's binary_logloss: 0.556633
# [182]	valid_0's binary_logloss: 0.556566
# [183]	valid_0's binary_logloss: 0.556519
# [184]	valid_0's binary_logloss: 0.556444
# [185]	valid_0's binary_logloss: 0.55637
# [186]	valid_0's binary_logloss: 0.55631
# [187]	valid_0's binary_logloss: 0.556261
# [188]	valid_0's binary_logloss: 0.556208
# [189]	valid_0's binary_logloss: 0.556157
# [190]	valid_0's binary_logloss: 0.556104
# [191]	valid_0's binary_logloss: 0.556056
# [192]	valid_0's binary_logloss: 0.556007
# [193]	valid_0's binary_logloss: 0.555943
# [194]	valid_0's binary_logloss: 0.555879
# [195]	valid_0's binary_logloss: 0.555818
# [196]	valid_0's binary_logloss: 0.555764
# [197]	valid_0's binary_logloss: 0.555702
# [198]	valid_0's binary_logloss: 0.555646
# [199]	valid_0's binary_logloss: 0.555599
# [200]	valid_0's binary_logloss: 0.55555
# [201]	valid_0's binary_logloss: 0.555499
# [202]	valid_0's binary_logloss: 0.555446
# [203]	valid_0's binary_logloss: 0.555386
# [204]	valid_0's binary_logloss: 0.555336
# [205]	valid_0's binary_logloss: 0.555279
# [206]	valid_0's binary_logloss: 0.555213
# [207]	valid_0's binary_logloss: 0.555154
# [208]	valid_0's binary_logloss: 0.555105
# [209]	valid_0's binary_logloss: 0.555047
# [210]	valid_0's binary_logloss: 0.555007
# [211]	valid_0's binary_logloss: 0.554946
# [212]	valid_0's binary_logloss: 0.554892
# [213]	valid_0's binary_logloss: 0.55483
# [214]	valid_0's binary_logloss: 0.554792
# [215]	valid_0's binary_logloss: 0.554738
# [216]	valid_0's binary_logloss: 0.55469
# [217]	valid_0's binary_logloss: 0.554643
# [218]	valid_0's binary_logloss: 0.554594
# [219]	valid_0's binary_logloss: 0.554549
# [220]	valid_0's binary_logloss: 0.55451
# [221]	valid_0's binary_logloss: 0.554465
# [222]	valid_0's binary_logloss: 0.554421
# [223]	valid_0's binary_logloss: 0.554372
# [224]	valid_0's binary_logloss: 0.554319
# [225]	valid_0's binary_logloss: 0.554274
# [226]	valid_0's binary_logloss: 0.554232
# [227]	valid_0's binary_logloss: 0.554186
# [228]	valid_0's binary_logloss: 0.554145
# [229]	valid_0's binary_logloss: 0.554092
# [230]	valid_0's binary_logloss: 0.554046
# [231]	valid_0's binary_logloss: 0.553998
# [232]	valid_0's binary_logloss: 0.553959
# [233]	valid_0's binary_logloss: 0.55391
# [234]	valid_0's binary_logloss: 0.553875
# [235]	valid_0's binary_logloss: 0.553831
# [236]	valid_0's binary_logloss: 0.553793
# [237]	valid_0's binary_logloss: 0.55376
# [238]	valid_0's binary_logloss: 0.55372
# [239]	valid_0's binary_logloss: 0.553675
# [240]	valid_0's binary_logloss: 0.553645
# [241]	valid_0's binary_logloss: 0.553604
# [242]	valid_0's binary_logloss: 0.553558
# [243]	valid_0's binary_logloss: 0.553513
# [244]	valid_0's binary_logloss: 0.553468
# [245]	valid_0's binary_logloss: 0.553422
# [246]	valid_0's binary_logloss: 0.553375
# [247]	valid_0's binary_logloss: 0.553336
# [248]	valid_0's binary_logloss: 0.5533
# [249]	valid_0's binary_logloss: 0.553267
# [250]	valid_0's binary_logloss: 0.553236
# [251]	valid_0's binary_logloss: 0.553192
# [252]	valid_0's binary_logloss: 0.553157
# [253]	valid_0's binary_logloss: 0.553112
# [254]	valid_0's binary_logloss: 0.553071
# [255]	valid_0's binary_logloss: 0.553039
# [256]	valid_0's binary_logloss: 0.553015
# [257]	valid_0's binary_logloss: 0.552963
# [258]	valid_0's binary_logloss: 0.552927
# [259]	valid_0's binary_logloss: 0.552883
# [260]	valid_0's binary_logloss: 0.55284
# [261]	valid_0's binary_logloss: 0.552809
# [262]	valid_0's binary_logloss: 0.55278
# [263]	valid_0's binary_logloss: 0.552732
# [264]	valid_0's binary_logloss: 0.552704
# [265]	valid_0's binary_logloss: 0.55267
# [266]	valid_0's binary_logloss: 0.55264
# [267]	valid_0's binary_logloss: 0.552616
# [268]	valid_0's binary_logloss: 0.552582
# [269]	valid_0's binary_logloss: 0.552548
# [270]	valid_0's binary_logloss: 0.552517
# [271]	valid_0's binary_logloss: 0.552493
# [272]	valid_0's binary_logloss: 0.552459
# [273]	valid_0's binary_logloss: 0.552427
# [274]	valid_0's binary_logloss: 0.552398
# [275]	valid_0's binary_logloss: 0.55236
# [276]	valid_0's binary_logloss: 0.552333
# [277]	valid_0's binary_logloss: 0.552298
# [278]	valid_0's binary_logloss: 0.552267
# [279]	valid_0's binary_logloss: 0.552245
# [280]	valid_0's binary_logloss: 0.552211
# [281]	valid_0's binary_logloss: 0.552164
# [282]	valid_0's binary_logloss: 0.552133
# [283]	valid_0's binary_logloss: 0.552107
# [284]	valid_0's binary_logloss: 0.55208
# [285]	valid_0's binary_logloss: 0.552056
# [286]	valid_0's binary_logloss: 0.552021
# [287]	valid_0's binary_logloss: 0.551985
# [288]	valid_0's binary_logloss: 0.551954
# [289]	valid_0's binary_logloss: 0.551922
# [290]	valid_0's binary_logloss: 0.55189
# [291]	valid_0's binary_logloss: 0.551863
# [292]	valid_0's binary_logloss: 0.551837
# [293]	valid_0's binary_logloss: 0.551795
# [294]	valid_0's binary_logloss: 0.55177
# [295]	valid_0's binary_logloss: 0.55174
# [296]	valid_0's binary_logloss: 0.551708
# [297]	valid_0's binary_logloss: 0.55168
# [298]	valid_0's binary_logloss: 0.551652
# [299]	valid_0's binary_logloss: 0.551611
# [300]	valid_0's binary_logloss: 0.551568
# accuracy: 0.7116786275996817

# %%
new_pred = ["adamı hasta etmeyin oğlum"]
new_pred = tfidf.transform(new_pred)
bst.predict(new_pred)
# Out:
# array([0.27503364])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
